# %%
from keras.datasets import fashion_mnist


import tensorflow as tf


import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np

# %%
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()


print('Train: X = ', trainX.shape)
print('Test: X = ', testX.shape)

trainX= trainX/ 255.0
testX= testX/ 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Train: X =  (60000, 28, 28)
# Test: X =  (10000, 28, 28)

# %%
for i in range(1, 10):


    plt.subplot(3, 3, i)


    plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))


plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    trainX, trainy,
    epochs=10,
    validation_data = (testX, testy))
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.4954 - accuracy: 0.8271 - val_loss: 0.4208 - val_accuracy: 0.8495
# Epoch 2/10
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3762 - accuracy: 0.8637 - val_loss: 0.3743 - val_accuracy: 0.8637
# Epoch 3/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3353 - accuracy: 0.8770 - val_loss: 0.3823 - val_accuracy: 0.8600
# Epoch 4/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3151 - accuracy: 0.8847 - val_loss: 0.3604 - val_accuracy: 0.8696
# Epoch 5/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2959 - accuracy: 0.8909 - val_loss: 0.3504 - val_accuracy: 0.8735
# Epoch 6/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2811 - accuracy: 0.8965 - val_loss: 0.3398 - val_accuracy: 0.8780
# Epoch 7/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2679 - accuracy: 0.9019 - val_loss: 0.3397 - val_accuracy: 0.8813
# Epoch 8/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2569 - accuracy: 0.9041 - val_loss: 0.3400 - val_accuracy: 0.8786
# Epoch 9/10
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2481 - accuracy: 0.9075 - val_loss: 0.3396 - val_accuracy: 0.8793
# Epoch 10/10
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2397 - accuracy: 0.9107 - val_loss: 0.3399 - val_accuracy: 0.8826

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend(loc='lower right')
